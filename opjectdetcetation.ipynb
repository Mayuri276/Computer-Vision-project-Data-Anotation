# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8 model
model = YOLO("yolov8n.pt")   # small, fast model

# Perform object detection
results = model("group.jpeg", save=True)

# Show results
results[0].show()
# Out:
# image 1/1 C:\yono 11\group.jpeg: 640x480 12 persons, 1 backpack, 40.4ms
# Speed: 8.8ms preprocess, 40.4ms inference, 8.1ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to C:\yono 11\runs\detect\predict-7

# %%
import os
print(os.getcwd())
# Out:
# C:\yono 11

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8 model
model = YOLO("yolov8n.pt")   # small, fast model

# Perform object detection
results = model("Collage.mp4", save=True)
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/347) C:\yono 11\Collage.mp4: 640x384 6 persons, 1 backpack, 39.9ms
# video 1/1 (frame 2/347) C:\yono 11\Collage.mp4: 640x384 6 persons, 1 backpack, 31.5ms
# video 1/1 (frame 3/347) C:\yono 11\Collage.mp4: 640x384 7 persons, 1 backpack, 28.5ms
# video 1/1 (frame 4/347) C:\yono 11\Collage.mp4: 640x384 5 persons, 1 backpack, 1 suitcase, 22.9ms
# ...

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8 model
model = YOLO("yolov8n.pt")   # small, fast model

# Perform object detection
results = model("mayu.jpg", save=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 7
#       3 # Load a pretrained YOLOv8 model
#       4 model = YOLO("yolov8n.pt")   # small, fast model
#       5
#       6 # Perform object detection
# ----> 7 results = model("mayu.jpg", save=True)
#
# File C:\yono 11\myvenv\Lib\site-packages\ultralytics\engine\model.py:177, in Model.__call__(self, source, stream, **kwargs)
#     149 def __call__(
#     150     self,
#     151     source: str | Path | int | Image.Image | list | tuple | np.ndarray | torch.Tensor = None,
#     152     stream: bool = False,
#     153     **kwargs: Any,
#     154 ) -> list:
#     155     """Alias for the predict method, enabling the model instance to be callable for predictions.
#     156
#     157     This method simplifies the process of making predictions by allowing the model instance to be called directly
# ...

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8 model
model = YOLO("yolov8n.pt")   # small, fast model

# Perform object detection
results = model("mayu.jpg", save=True)

# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
######segmentation Model


from ultralytics import YOLO

# Load a pretrained YOLOv8 model
model = YOLO("YOLO11n-seg.pt")   # small, fast model

# Perform object detection
results = model("mayu.jpeg", save=True)

# Show results
results[0].show()
# Out:
# image 1/1 C:\yono 11\mayu.jpeg: 640x480 1 person, 70.3ms
# Speed: 7.6ms preprocess, 70.3ms inference, 8.6ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to C:\yono 11\runs\segment\predict-3

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8 model
model = YOLO("YOLO11n-seg.pt")   # small, fast model

# Perform object detection
results = model("Collage.mp4", save=True)

# Show results
results[0].show()
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/347) C:\yono 11\Collage.mp4: 640x384 6 persons, 1 suitcase, 1063.6ms
# video 1/1 (frame 2/347) C:\yono 11\Collage.mp4: 640x384 7 persons, 2 suitcases, 31.2ms
# video 1/1 (frame 3/347) C:\yono 11\Collage.mp4: 640x384 5 persons, 1 handbag, 2 suitcases, 50.2ms
# video 1/1 (frame 4/347) C:\yono 11\Collage.mp4: 640x384 7 persons, 1 suitcase, 28.7ms
# ...

# %%
from ultralytics import YOLO

# Load YOLOv11 pose model (nano version)
model = YOLO("yolo11n-pose.pt")   # lowercase name

# Perform pose estimation
results = model("mayu.jpeg", save=True)
results[0].show()
# Out:
# image 1/1 C:\yono 11\mayu.jpeg: 640x480 1 person, 37.3ms
# Speed: 7.2ms preprocess, 37.3ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to C:\yono 11\runs\pose\predict-3

# %%
from ultralytics import YOLO

# Load YOLOv11 pose model (nano version)
model = YOLO("yolo11n-pose.pt")   # lowercase name

# Perform pose estimation
results = model("group.jpeg", save=True)
results[0].show()
# Out:
# image 1/1 C:\yono 11\group.jpeg: 640x480 11 persons, 45.3ms
# Speed: 5.0ms preprocess, 45.3ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to C:\yono 11\runs\pose\predict-4

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8 model
model = YOLO("yolov8n.pt")   # small, fast model

# Perform object detection
results = model("group.jpeg", save=True)
# Out:
# image 1/1 C:\yono 11\group.jpeg: 640x480 12 persons, 1 backpack, 38.0ms
# Speed: 4.7ms preprocess, 38.0ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to C:\yono 11\runs\detect\predict-4

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8 model
model = YOLO("yolov8n.pt")   # small, fast model

# Perform object detection
results = model("group.jpeg", save=True)

# Show results
results[0].show()
# Out:
# image 1/1 C:\yono 11\group.jpeg: 640x480 12 persons, 1 backpack, 35.9ms
# Speed: 5.2ms preprocess, 35.9ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to C:\yono 11\runs\detect\predict-7

# %%
from ultralytics import YOLO

# Load YOLOv11 pose model (nano version)
model = YOLO("yolo11n-cls.pt")   # lowercase name

# Perform pose estimation
results = model("group.jpeg", save=True)
results[0].show()
# Out:
# ...
#
# ...
# image 1/1 C:\yono 11\group.jpeg: 224x224 unicycle 0.10, mountain_bike 0.07, valley 0.06, bow_tie 0.05, jersey 0.05, 13.7ms
# Speed: 35.5ms preprocess, 13.7ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to C:\yono 11\runs\classify\predict

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8 model
model = YOLO("yolo11n-obb.pt")   # small, fast model

# Perform object detection on an image
results = model("vid.mp4", save=True)
# Out:
# WARNING
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/383) C:\yono 11\vid.mp4: 1024x576 (no detections), 72.2ms
# video 1/1 (frame 2/383) C:\yono 11\vid.mp4: 1024x576 (no detections), 29.6ms
# video 1/1 (frame 3/383) C:\yono 11\vid.mp4: 1024x576 (no detections), 30.0ms
# video 1/1 (frame 4/383) C:\yono 11\vid.mp4: 1024x576 (no detections), 37.4ms
# video 1/1 (frame 5/383) C:\yono 11\vid.mp4: 1024x576 (no detections), 37.3ms
# ...
